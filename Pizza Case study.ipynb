# %%
Crustbase={"thin":4,"thick":6.5,"wood fired":8.50}
Cheese_style={"Chedder":5,"Colby":5,"Edam":5,"Emmental":5,"Gruyere":5,"Mozzrela":5,"provolone":5,"Ricotta":5}
Topping_Choices={"Tomato":0.75,"Mushroom":0.75,"Pepperoni":0.50,"Onion":0.25,"Black Olives":0.75,"Green Peppers":0.50,"Anchovies":0.25,"Garlic":0.50,"Ham":1.50,"Bacon":1.25}
a=str(input("Enter the Name of the customer: "))
b=int(input('Enter the total no of Pizza   : '))
amount=0
m={}
x=0
y=0
z=0
print ("Available CrustBase and its Amount is :")
for i,j in Crustbase.items():
    print("----- %s cost Rs: %f "%(i,j))
print ("Available Cheese style and its Amount is :")
for i,j in Cheese_style.items():
    print("----- %s cost Rs: %f "%(i,j))
print ("Available Topping Choices and its Amount is :")
for i,j in Topping_Choices.items():
    print("----- %s cost Rs: %f "%(i,j))
print()
for i in range(1,b+1):
    c=input("Enter Crust Base for pizza %d:"%(i))
    for j in Crustbase.keys():#to check entered crustbase is presenr in given list or not
        if (c==j):#checking by if condition
            x=Crustbase[j] #x me j ki value store
            amount=amount+Crustbase[j] #amount 0 plus amount of crustbase
            if (m.get(j,0)==0): #m={}#j = "thin"
                m[j]=x
            else:
                m[j]=x*i
    d=input("Enter Cheese style for pizza %d .Only three chesse style are allowed:"%(i))
    e=d.split() #will print cheese style with space
    while (len(e)>3): #if entered cheese style>3, then message will be displayed
        print("Maximum Chesse style allowed is 3:Renter Cheese type ")
        d1=input("Enter Cheese style for pizza %d .Only three chesse style are allowed:"%(i))
        e=d1.split() #d1=if user chooses only 3, 

    for j in e:
        for k in Cheese_style.keys():
            if (j==k):
                y=Cheese_style[j]
                amount=amount+Cheese_style[j]
                if (m.get(j,0)==0):
                    m[j]=y
                else:
                    m[j]=y*i
    f=input("Enter Topping Choices for pizza %d .Only Seven chesse style are allowed:"%(i))
    g=f.split()
    while (len(g)>7):
        print("Maximum Chesse style allowed is 7:Renter Topping Choices ")
        f1=input("Enter Cheese style for pizza %d .Only Seven Topping Choices are allowed:"%(i))
        g=f1.split() #f1<=7
    for j in g:
        for k in Topping_Choices.keys():
            if (j==k):
                z=Topping_Choices[j]
                amount=amount+Topping_Choices[j]
                if (m.get(j,0)==0):
                    m[j]=z
                else:
                    m[j]=z*i
print()
print("The Cost detail of variety of Crust base ,cheese burst ,Topping choices is below ")
for i,j in m.items():
    print("Total Cost of %s is Rs %f :"%(i,j))
print()
print("The total amount of Pizza cost is Rs :",amount)
# Out:
# Enter the Name of the customer: abc
# Enter the total no of Pizza   : 1
# Available CrustBase and its Amount is :
# ----- thin cost Rs: 4.000000
# ----- thick cost Rs: 6.500000
# ----- wood fired cost Rs: 8.500000
# Available Cheese style and its Amount is :
# ----- Chedder cost Rs: 5.000000
# ----- Colby cost Rs: 5.000000
# ----- Edam cost Rs: 5.000000
# ----- Emmental cost Rs: 5.000000
# ----- Gruyere cost Rs: 5.000000
# ----- Mozzrela cost Rs: 5.000000
# ----- provolone cost Rs: 5.000000
# ----- Ricotta cost Rs: 5.000000
# Available Topping Choices and its Amount is :
# ----- Tomato cost Rs: 0.750000
# ----- Mushroom cost Rs: 0.750000
# ----- Pepperoni cost Rs: 0.500000
# ----- Onion cost Rs: 0.250000
# ----- Black Olives cost Rs: 0.750000
# ----- Green Peppers cost Rs: 0.500000
# ----- Anchovies cost Rs: 0.250000
# ----- Garlic cost Rs: 0.500000
# ----- Ham cost Rs: 1.500000
# ----- Bacon cost Rs: 1.250000
#
# Enter Crust Base for pizza 1:thin
# ...
